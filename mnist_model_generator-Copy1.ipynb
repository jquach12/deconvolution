# %%
# -*- coding: utf-8 -*-
"""
nn package
==========
We’ve redesigned the nn package, so that it’s fully integrated with
autograd. Let's review the changes.
**Replace containers with autograd:**
    You no longer have to use Containers like ``ConcatTable``, or modules like
    ``CAddTable``, or use and debug with nngraph. We will seamlessly use
    autograd to define our neural networks. For example,
    * ``output = nn.CAddTable():forward({input1, input2})`` simply becomes
      ``output = input1 + input2``
    * ``output = nn.MulConstant(0.5):forward(input)`` simply becomes
      ``output = input * 0.5``
**State is no longer held in the module, but in the network graph:**
    Using recurrent networks should be simpler because of this reason. If
    you want to create a recurrent network, simply use the same Linear layer
    multiple times, without having to think about sharing weights.
    .. figure:: /_static/img/torch-nn-vs-pytorch-nn.png
       :alt: torch-nn-vs-pytorch-nn
       torch-nn-vs-pytorch-nn
**Simplified debugging:**
    Debugging is intuitive using Python’s pdb debugger, and **the debugger
    and stack traces stop at exactly where an error occurred.** What you see
    is what you get.
Example 1: ConvNet
------------------
Let’s see how to create a small ConvNet.
All of your networks are derived from the base class ``nn.Module``:
-  In the constructor, you declare all the layers you want to use.
-  In the forward function, you define how your model is going to be
   run, from input to output
"""

import torch
import torch.nn as nn
import torch.nn.functional as F


class MNISTConvNet(nn.Module):

    def __init__(self):
        # this is the place where you instantiate all your modules
        # you can later access them using the same names you've given them in
        # here
        super(MNISTConvNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, 5)
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(10, 20, 5)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    # it's the forward function that defines the network structure
    # we're accepting only a single input in here, but if you want,
    # feel free to use more
    def forward(self, input):
        x = self.pool1(F.relu(self.conv1(input)))
        x = self.pool2(F.relu(self.conv2(x)))

        # in your model definition you can go full crazy and use arbitrary
        # python code to define your model structure
        # all these are perfectly legal, and will be handled correctly
        # by autograd:
        # if x.gt(0) > x.numel() / 2:
        #      ...
        #
        # you can even do a loop and reuse the same module inside it
        # modules no longer hold ephemeral state, so you can use them
        # multiple times during your forward pass
        # while x.norm(2) < 10:
        #    x = self.conv1(x)

        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return x

###############################################################
# Let's use the defined ConvNet now.
# You create an instance of the class first.


net = MNISTConvNet()
print(net)

########################################################################
# .. note::
#
#     ``torch.nn`` only supports mini-batches The entire ``torch.nn``
#     package only supports inputs that are a mini-batch of samples, and not
#     a single sample.
#
#     For example, ``nn.Conv2d`` will take in a 4D Tensor of
#     ``nSamples x nChannels x Height x Width``.
#
#     If you have a single sample, just use ``input.unsqueeze(0)`` to add
#     a fake batch dimension.
#
# Create a mini-batch containing a single sample of random data and send the
# sample through the ConvNet.

input = torch.randn(1, 1, 28, 28)
out = net(input)
print(out.size())

########################################################################
# Define a dummy target label and compute error using a loss function.

target = torch.tensor([3], dtype=torch.long)
loss_fn = nn.CrossEntropyLoss()  # LogSoftmax + ClassNLL Loss
err = loss_fn(out, target)
err.backward()

print(err)

########################################################################
# The output of the ConvNet ``out`` is a ``Tensor``. We compute the loss
# using that, and that results in ``err`` which is also a ``Tensor``.
# Calling ``.backward`` on ``err`` hence will propagate gradients all the
# way through the ConvNet to it’s weights
#
# Let's access individual layer weights and gradients:

print(net.conv1.weight.grad.size())

########################################################################
print(net.conv1.weight.data.norm())  # norm of the weight
print(net.conv1.weight.grad.data.norm())  # norm of the gradients

########################################################################
# Forward and Backward Function Hooks
# -----------------------------------
#
# We’ve inspected the weights and the gradients. But how about inspecting
# / modifying the output and grad\_output of a layer?
#
# We introduce **hooks** for this purpose.
#
# You can register a function on a ``Module`` or a ``Tensor``.
# The hook can be a forward hook or a backward hook.
# The forward hook will be executed when a forward call is executed.
# The backward hook will be executed in the backward phase.
# Let’s look at an example.
#
# We register a forward hook on conv2 and print some information


def printnorm(self, input, output):
    # input is a tuple of packed inputs
    # output is a Tensor. output.data is the Tensor we are interested
    print('Inside ' + self.__class__.__name__ + ' forward')
    print('')
    print('input: ', type(input))
    print('input[0]: ', type(input[0]))
    print('output: ', type(output))
    print('')
    print('input size:', input[0].size())
    print('output size:', output.data.size())
    print('output norm:', output.data.norm())


net.conv2.register_forward_hook(printnorm)

out = net(input)

########################################################################
#
# We register a backward hook on conv2 and print some information


def printgradnorm(self, grad_input, grad_output):
    print('Inside ' + self.__class__.__name__ + ' backward')
    print('Inside class:' + self.__class__.__name__)
    print('')
    print('grad_input: ', type(grad_input))
    print('grad_input[0]: ', type(grad_input[0]))
    print('grad_output: ', type(grad_output))
    print('grad_output[0]: ', type(grad_output[0]))
    print('')
    print('grad_input size:', grad_input[0].size())
    print('grad_output size:', grad_output[0].size())
    print('grad_input norm:', grad_input[0].norm())


net.conv2.register_backward_hook(printgradnorm)

out = net(input)
err = loss_fn(out, target)
err.backward()
# Out:
# MNISTConvNet(
#   (conv1): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=320, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
# )
# torch.Size([1, 10])
# tensor(2.2835)
# torch.Size([10, 1, 5, 5])
# tensor(1.8193)
# tensor(0.5207)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([1, 10, 12, 12])
# output size: torch.Size([1, 20, 8, 8])
# output norm: tensor(13.4471)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([1, 10, 12, 12])
# output size: torch.Size([1, 20, 8, 8])
# output norm: tensor(13.4471)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([1, 10, 12, 12])
# grad_output size: torch.Size([1, 20, 8, 8])
# grad_input norm: tensor(0.1010)

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

losses = []

for epoch in range(1):  # loop over the dataset multiple times
    with torch.enable_grad(): #hmm wat does this do...
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # get the inputs
            inputs, labels = data

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            if i % 2000 == 1999:    # print every 2000 mini-batches
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 2000))

                losses.append(running_loss / 2000)
                running_loss = 0.0

print('Finished Training')
# Out:
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(19.8085)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.8887)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.2112)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.6772)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.2890)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        4.2365)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.2466)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.5423)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(19.7025)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.2976)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.9073)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        4.0270)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.8245)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.8927)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.3598)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.5932)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.0168)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.3117)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.2396)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.5945)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.0535)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        4.2320)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.4458)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        4.9944)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.0688)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.6637)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.9219)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.3614)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.8661)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.3223)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.7556)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.3139)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.7223)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.8966)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.1666)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.3114)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.5652)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.3498)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.0871)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.8666)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.7361)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.2989)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.2732)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.3515)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.2749)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.7356)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.5816)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        4.0527)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.6704)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.9458)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(22.1150)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.3570)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.7496)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.5605)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(22.4439)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.2529)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.9625)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.4815)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.7938)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.6119)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.6323)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.1481)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(22.2775)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.9276)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(22.1117)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.9808)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.6868)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.4765)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(22.3037)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.7419)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.5417)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.1268)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.9386)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.5070)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.6290)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.3823)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.8191)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.1928)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.8132)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.2679)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.5267)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.9209)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(22.3267)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.0765)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(22.0117)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.1485)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.8281)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.0599)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.9688)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.6285)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(22.0766)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.9963)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.2370)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.0849)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.6245)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.1666)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.7735)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.6731)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.4975)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.0136)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(22.0264)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.8756)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.0851)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.5614)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.3858)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.0791)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(22.0290)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.8286)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.7138)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-03 *
#        9.6416)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.2216)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.0848)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.3497)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-03 *
#        9.8118)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.4424)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.5955)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.3671)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        4.2963)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.4786)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.2683)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.7048)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.2566)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.7047)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.9825)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.6412)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.7813)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.9996)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.9431)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.4170)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.6536)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.5763)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.6019)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.3048)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.9767)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.8704)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.2021)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.5910)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.5199)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.7860)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.9379)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.5540)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        4.4955)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.9513)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.5586)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.5833)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.4831)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(22.0513)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.0386)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.6957)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.8458)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.4241)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.1250)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.7065)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.3774)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.4276)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-03 *
#        9.3205)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.1511)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.6758)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(20.8850)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.9779)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.8384)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.0365)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.4862)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.0679)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.7596)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        4.3251)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(22.0517)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.1512)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.2731)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.7644)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.1208)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.7314)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.7992)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.3642)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(21.8476)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# ...
# grad_input norm: tensor(0.3140)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(115.3354)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-03 *
#        7.0257)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(117.6728)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(0.1330)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(122.4812)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(0.1715)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(124.1677)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        6.4812)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(117.6180)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(0.2627)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(101.6842)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        2.8351)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(122.1182)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(0.1095)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(106.0421)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.2782)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(118.0400)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-03 *
#        6.8354)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(119.1726)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.0619)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(114.3867)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(0.1495)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(124.5166)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        8.3280)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(112.0813)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(0.2039)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(93.6963)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(0.1647)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(108.5641)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(0.1989)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(118.3602)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(0.2474)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(123.7040)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        1.4702)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(113.4502)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(0.1087)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(108.4323)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        6.4214)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(126.5115)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:
# Process Process-17:
# Process Process-18:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/silver/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/silver/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/silver/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/silver/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(0.1837)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(109.0241)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(0.1123)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(127.4377)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        8.1557)
# Inside Conv2d forward
#
# input:  <class 'tuple'>
# input[0]:  <class 'torch.Tensor'>
# output:  <class 'torch.Tensor'>
#
# input size: torch.Size([4, 10, 12, 12])
# output size: torch.Size([4, 20, 8, 8])
# output norm: tensor(101.5652)
# Inside Conv2d backward
# Inside class:Conv2d
#
# grad_input:  <class 'tuple'>
# grad_input[0]:  <class 'torch.Tensor'>
# grad_output:  <class 'tuple'>
# grad_output[0]:  <class 'torch.Tensor'>
#
# grad_input size: torch.Size([4, 10, 12, 12])
# grad_output size: torch.Size([4, 20, 8, 8])
# grad_input norm: tensor(1.00000e-02 *
#        3.9551)
#   File "/Users/silver/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x109e2ca20>>
# Traceback (most recent call last):
#   File "/Users/silver/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 347, in __del__
#     def __del__(self):
#   File "/Users/silver/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 178, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 63287) exited unexpectedly with exit code 1.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-e0c6b0729e20> in <module>()
#      19             outputs = net(inputs)
#      20             loss = criterion(outputs, labels)
# ---> 21             loss.backward()
#      22
#      23             optimizer.step()
#
# ~/anaconda3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:
#   File "/Users/silver/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/Users/silver/anaconda3/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/Users/silver/anaconda3/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/Users/silver/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/silver/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/silver/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/silver/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/silver/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/silver/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
